# %%
# %load_ext lab_black

import numpy as np
import pandas as pd
import os
import pyreadr
from glob import glob
import matplotlib.pyplot as plt

# %%
PHENO_DIR = "/u/project/pasaniuc/ziqixu09/phenotype/"

# %%
pheno_eid = pd.read_csv(os.path.join(PHENO_DIR, "pheno.csv"), usecols=["eid"])[
    "eid"
].values.astype(str)
df_covar = pd.read_csv(os.path.join(PHENO_DIR, "covar.csv"), index_col=0)[
    ["AGE", "SEX", "DEPRIVATION_INDEX"] + [f"PC{i}" for i in range(1, 17)]
]
df_covar.index = df_covar.index.astype(str)
df_covar = pd.merge(
    pd.DataFrame(
        {"FID": df_covar.index, "IID": df_covar.index},
        index=df_covar.index,
    ),
    df_covar,
    left_index=True,
    right_index=True,
)
df_covar.to_csv(
    "out/covar.tsv", sep="\t", index=False, float_format="%.6g", na_rep="NA"
)
assert np.all(df_covar.index == pheno_eid)

# %%
df_pheno = df_covar[["FID", "IID"]].copy()
df_pheno["PHENO"] = np.nan

for trait_type in ["quant", "binary"]:
    trait_dir = f"data/ukbb-{trait_type}-pheno/"
    for trait_f in glob(f"{trait_dir}/*.rds"):
        trait = trait_f.split("/")[-1].split(".")[0]
        trait_values = pyreadr.read_r(trait_f)[None].values
        df_pheno["PHENO"] = trait_values.astype(float)
        print(
            f"Proportion of non-NaNs: {trait}: {1 - df_pheno['PHENO'].isna().mean():.2g}"
        )
        df_pheno.to_csv(
            f"out/{trait}.tsv",
            sep="\t",
            index=False,
            float_format="%.6g",
            na_rep="NA",
        )
# Out:
# Proportion of non-NaNs: hand_grip_strength: 0.99
# Proportion of non-NaNs: log_waist_circ: 1
# Proportion of non-NaNs: log_hip_circ: 1
# Proportion of non-NaNs: height: 1
# Proportion of non-NaNs: log_pulse_rate: 0.94
# Proportion of non-NaNs: income: 0.85
# Proportion of non-NaNs: geek_time: 0.98
# Proportion of non-NaNs: log_sleep: 0.99
# Proportion of non-NaNs: more_evening: 0.89
# Proportion of non-NaNs: insomnia: 1
# Proportion of non-NaNs: water_intake: 0.99
# Proportion of non-NaNs: less_alcohol: 1
# Proportion of non-NaNs: darker_skin: 0.98
# Proportion of non-NaNs: darker_skin0: 0.98
# Proportion of non-NaNs: less_tanned: 0.97
# Proportion of non-NaNs: darker_hair: 0.94
# Proportion of non-NaNs: darker_hair0: 0.94
# Proportion of non-NaNs: log_age_first_sex: 0.86
# Proportion of non-NaNs: poorer_health: 0.99
# Proportion of non-NaNs: more_sunscreen: 0.99
# Proportion of non-NaNs: M_less_hair: 0.45
# Proportion of non-NaNs: F_menarche: 0.53
# Proportion of non-NaNs: F_age_first_birth: 0.37
# Proportion of non-NaNs: ankle_spacing: 0.56
# Proportion of non-NaNs: log_heel_BUA: 0.56
# Proportion of non-NaNs: log_heel_SoS: 0.56
# Proportion of non-NaNs: log_heel_BMD: 0.56
# Proportion of non-NaNs: F_length_menstrual_cycle: 0.094
# Proportion of non-NaNs: diastolic_BP: 0.94
# Proportion of non-NaNs: systolic_BP: 0.94
# Proportion of non-NaNs: logMAR: 0.26
# Proportion of non-NaNs: years_of_edu: 0.82
# Proportion of non-NaNs: sitting_height: 1
# Proportion of non-NaNs: birth_weight: 0.55
# Proportion of non-NaNs: neuroticism: 0.8
# Proportion of non-NaNs: FEV1: 0.71
# Proportion of non-NaNs: FVC: 0.71
# Proportion of non-NaNs: fluid_intelligence: 0.25
# Proportion of non-NaNs: avMSE: 0.23
# Proportion of non-NaNs: less_happy: 0.31
# Proportion of non-NaNs: less_happy_with_health: 0.31
# Proportion of non-NaNs: log_BMI: 1
# Proportion of non-NaNs: log_mean_carotid_IMT: 0.05
# Proportion of non-NaNs: fat_perc: 0.98
# Proportion of non-NaNs: log_fat_mass: 0.98
# Proportion of non-NaNs: log_fat_free_mass: 0.98
# Proportion of non-NaNs: log_water_mass: 0.98
# Proportion of non-NaNs: log_impedance: 0.98
# Proportion of non-NaNs: log_ventricular_rate: 0.075
# Proportion of non-NaNs: ECG_P_duration: 0.071
# Proportion of non-NaNs: log_ECG_QRS_duration: 0.075
# Proportion of non-NaNs: ECG_PQ_interval: 0.047
# Proportion of non-NaNs: ECG_QT_interval: 0.05
# Proportion of non-NaNs: ECG_QTC_interval: 0.05
# Proportion of non-NaNs: ECG_RR_interval: 0.05
# Proportion of non-NaNs: ECG_PP_interval: 0.049
# Proportion of non-NaNs: log_leukocyte: 0.97
# Proportion of non-NaNs: erythrocyte: 0.97
# Proportion of non-NaNs: haemoglobin: 0.97
# Proportion of non-NaNs: haematocrit_perc: 0.97
# Proportion of non-NaNs: MCV: 0.97
# Proportion of non-NaNs: MCH: 0.97
# Proportion of non-NaNs: erythrocyte_width: 0.97
# Proportion of non-NaNs: log_platelet: 0.97
# Proportion of non-NaNs: log_platelet_crit: 0.97
# Proportion of non-NaNs: log_platelet_volume: 0.97
# Proportion of non-NaNs: log_platelet_width: 0.97
# Proportion of non-NaNs: log_lymphocyte: 0.97
# Proportion of non-NaNs: log_monocyte: 0.97
# Proportion of non-NaNs: log_neutrophil: 0.97
# Proportion of non-NaNs: sodium_urine: 0.97
# Proportion of non-NaNs: lymphocyte_perc: 0.97
# Proportion of non-NaNs: monocyte_perc: 0.96
# Proportion of non-NaNs: neutrophil_perc: 0.97
# Proportion of non-NaNs: log_eosinophil_perc: 0.57
# Proportion of non-NaNs: log_basophil_perc: 0.02
# Proportion of non-NaNs: log_reticulocyte: 0.95
# Proportion of non-NaNs: reticulocyte_volume: 0.95
# Proportion of non-NaNs: sphered_cell_volume: 0.95
# Proportion of non-NaNs: immature_reticulocyte_frac: 0.95
# Proportion of non-NaNs: log_HLR_reticulocyte: 0.95
# Proportion of non-NaNs: log_microalbumin_urine: 0.31
# Proportion of non-NaNs: log_creatinine_urine: 0.97
# Proportion of non-NaNs: log_potassium_urine: 0.97
# Proportion of non-NaNs: albumin: 0.87
# Proportion of non-NaNs: log_ALP: 0.95
# Proportion of non-NaNs: log_ALT: 0.95
# Proportion of non-NaNs: apoA: 0.87
# Proportion of non-NaNs: apoB: 0.95
# Proportion of non-NaNs: log_AST: 0.95
# Proportion of non-NaNs: log_urea: 0.95
# Proportion of non-NaNs: calcium: 0.87
# Proportion of non-NaNs: cholesterol: 0.95
# Proportion of non-NaNs: log_creatinine: 0.95
# Proportion of non-NaNs: log_CRP: 0.95
# Proportion of non-NaNs: log_cystatinC: 0.95
# Proportion of non-NaNs: log_log_gammaGT: 0.95
# Proportion of non-NaNs: log_glucose: 0.87
# Proportion of non-NaNs: log_HbA1c: 0.95
# Proportion of non-NaNs: log_HDL: 0.87
# Proportion of non-NaNs: log_IGF1: 0.95
# Proportion of non-NaNs: LDL: 0.95
# Proportion of non-NaNs: log_lipoA: 0.76
# Proportion of non-NaNs: F_log_oestradiol: 0.12
# Proportion of non-NaNs: M_log_oestradiol: 0.038
# Proportion of non-NaNs: phosphate: 0.87
# Proportion of non-NaNs: log_SHBG: 0.86
# Proportion of non-NaNs: log_rheumatoid_factor: 0.084
# Proportion of non-NaNs: log_bilirubin: 0.95
# Proportion of non-NaNs: F_log_testosterone: 0.43
# Proportion of non-NaNs: M_log_testosterone: 0.43
# Proportion of non-NaNs: protein: 0.87
# Proportion of non-NaNs: log_triglycerides: 0.95
# Proportion of non-NaNs: urate: 0.95
# Proportion of non-NaNs: log_vitaminD: 0.91
# Proportion of non-NaNs: snoring: 0.93
# Proportion of non-NaNs: narcolepsy: 0.99
# Proportion of non-NaNs: left_handed: 0.98
# Proportion of non-NaNs: red_hair: 0.98
# Proportion of non-NaNs: no_sex: 0.88
# Proportion of non-NaNs: glasses: 1
# Proportion of non-NaNs: play_computer: 1
# Proportion of non-NaNs: bad_hearing: 0.96
# Proportion of non-NaNs: fall_1y: 1
# Proportion of non-NaNs: fracture_5y: 0.99
# Proportion of non-NaNs: F_irregular_menstrual_cycle: 0.12
# Proportion of non-NaNs: headaches_for_3m: 0.2
# Proportion of non-NaNs: depressed_for_1w: 0.33
# Proportion of non-NaNs: drink_alcohol: 0.96
# Proportion of non-NaNs: ever_smoked: 0.99
# Proportion of non-NaNs: myopia: 0.23
# Proportion of non-NaNs: ever_addicted: 0.31
# Proportion of non-NaNs: depression_stress_trauma: 0.18
# Proportion of non-NaNs: ever_cannabis: 0.29
# Proportion of non-NaNs: self_harm_thoughts: 0.32
# Proportion of non-NaNs: depression_feelings: 0.31
# Proportion of non-NaNs: abnormal_appetite: 0.31
# Proportion of non-NaNs: foreboding_feelings: 0.31
# Proportion of non-NaNs: hard_falling_asleep: 0.12
# Proportion of non-NaNs: sensitive_stomach: 0.32
# Proportion of non-NaNs: celiac_gluten: 0.35
